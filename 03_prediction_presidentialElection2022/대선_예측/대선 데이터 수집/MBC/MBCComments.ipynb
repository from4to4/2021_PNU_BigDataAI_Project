# %%
# 다음 뉴스 or MBC 뉴스
def whichNews(driver):
    try:
        a1 = driver.find_element_by_css_selector('#content > div > section.wrap_article > article > div.wrap_title')
#         print('MBC')
        return 'mbc'
    except:
        a1 = driver.find_element_by_css_selector('#cSub > div > h3')
        # print('다음')
        return 'daum'

# %%
# MBC - 더보기 계속 클릭하기
def clickMoreMBC(driver):
    import time
    
    while True:
        try:
            more_button = driver.find_element_by_css_selector('#commentBox > div.list_comment > div > button')
            more_button.click()
            # print('클릭 성공')
            time.sleep(2)
        except:
            break

# %%
# 다음 - 더보기 계속 클릭하기
def clickMoreDaum(driver):
    import time
    from selenium.webdriver.common.keys import Keys

    while True:
        try:
            more_button = driver.find_element_by_css_selector('#alex-area > div > div > div > div.cmt_box > div.alex_more > button')
            # more_button.sendKeys(Keys.ENTER)
            more_button.click()
            print('댓글 더보기 클릭 성공')
            time.sleep(2)
        except:
            break

# %%
# 다음 - 답글 더보기 계속 클릭하기
def clickMoreReplyDaum(driver):
    import time
    from selenium.webdriver.common.keys import Keys

    while True:
        try:
            more_button = driver.find_element_by_css_selector('div > div.reply_wrap > div.alex_more > button')
            # more_button.sendKeys(Keys.ENTER)
            more_button.click()
            print('답글 더보기 클릭 성공')
            time.sleep(2)
        except:
            break

# %%
# 다음 하나의 기사에 댓글이 있는지 확인
def areAnyCommentsDaum(driver):
    a1 = driver.find_element_by_css_selector('#alexCounter > span').text
    #print(a1)
    
    if a1 == '0':
        # print('댓글 없음')
        return False
    else:
        # print('댓글 있음')
        return True

# %%
# MBC - 하나의 기사에 댓글이 있는지 확인
def areAnyCommentsMBC(driver):
    a1 = driver.find_element_by_css_selector('#commentBox > div.comment_numb').text
    #print(a1)
    
    if a1 == '0':
        # print('댓글 없음')
        return False
    else:
        # print('댓글 있음')
        return True

# %%
# 다음 - 한 기사의 댓글 추출
def getCommentDaum(driver):
    
    import os
    import time
    import pandas as pd
    from selenium.webdriver.common.keys import Keys

    
    # 데이터를 담을 딕셔너리
    comment_dict = {
        '제목' : [],
        '날짜' : [],
        '작성자' : [],
        '작성일' : [],
        '댓글' : []
    }
    
    # 기사 제목 & 날짜 태그
    a1 = driver.find_element_by_css_selector('#cSub > div ')
    
    # 기사 제목 
    data1 = a1.find_element_by_css_selector('h3').text
    # print(data1)

    # 날짜 
    data2 = a1.find_element_by_css_selector('span > span:nth-child(2) > span').text
    # print(data2)
    
    # 댓글 태그
    a2 = driver.find_elements_by_css_selector('#alex-area > div > div > div > div.cmt_box > ul.list_comment > li')
    # print(len(a2))
        
    # 댓글 수만큼 반복
    for a3 in a2:

        # 작성자
        data3 = a3.find_element_by_css_selector('div > strong > span > a').text
        # print(data3)

        # 댓글 작성일
        data4 = a3.find_element_by_css_selector('div > strong > span > span.txt_date').text
        # print(data4)
        
        
        # 댓글 
        try:
            data5 = a3.find_element_by_css_selector('div > p').text
        except:
            print('가려진 댓글 그냥 무시하기')
            # coverd_button = a6.find_element_by_css_selector('div > div.covered_msg_wrap.screened > div > span.covered_txt.uncover > span > span.clickable')
            # coverd_button.send_keys(Keys.ENTER)
            # time.sleep(2)
            # print('가려진 댓글 읽기')
            # data5 = a3.find_element_by_css_selector('div > p').text
            continue
            
        # 저장
        comment_dict['제목'].append(data1)
        comment_dict['날짜'].append(data2)
        comment_dict['작성자'].append(data3)
        comment_dict['작성일'].append(data4)
        comment_dict['댓글'].append(data5)

        # 답글 버튼 
        a4 = a3.find_element_by_css_selector('div > div > span.box_inner > button').text
        print(a4[-2:])
        
        # 답글 버튼 클릭하기
        if a4[-2:] != '작성':
            # print('클릭시도')
            reply_button = a3.find_element_by_css_selector('div > div.box_reply > span.box_inner > button')        
            reply_button.send_keys(Keys.ENTER)
#             reply_button.click()
            time.sleep(2)
            # print('클릭 완료')
        
            # 답글 더보기 버튼 클릭
            clickMoreReplyDaum(a3)

            # 답글 태그
            a5 = a3.find_elements_by_css_selector('div > div.reply_wrap > div.cont_wrap > ul.list_reply > li')
            # print(len(a5))

            # 답글 수만큼 반복
            for a6 in a5:

                # 작성자
                data3 = a6.find_element_by_css_selector('div > div > strong > span.info_author > a').text
                # print(data3)

                # 작성일
                data4 = a6.find_element_by_css_selector('div > div > strong > span.info_author > span.txt_date').text
                # print(data4)

                # 답글
                try:
                    data5 = a6.find_element_by_css_selector('div > div > p').text
                except:
                    print('가려진 댓글 그냥 패스하기')
                    # print('가려진 댓글 읽기 시도')
                    # coverd_button = a6.find_element_by_css_selector('div > div > div.covered_msg_wrap.screened > div > span.covered_txt.uncover > span > span.clickable')
                    # coverd_button.send_keys(Keys.ENTER)
                    # time.sleep(2)
                    # print('가려진 댓글 읽기')
                    continue


                # print(data5)

                comment_dict['제목'].append(data1)
                comment_dict['날짜'].append(data2)
                comment_dict['작성자'].append(data3)
                comment_dict['작성일'].append(data4)
                comment_dict['댓글'].append(data5)
        
    df = pd.DataFrame(comment_dict)
    df['날짜'] = df['날짜'].str.replace('입력 ', '')
    df['날짜'] = pd.to_datetime(df['날짜'])
    df['작성일'] = pd.to_datetime(df['작성일'])
    display(df)

    FILENAME = 'mbc_comment_daum.csv'
    if os.path.exists(FILENAME) == False:
        # 파일이 없을 경우
        df.to_csv(FILENAME, encoding='utf-8-sig', index=False)
    else:
        # mode='a' : 기존 것 뒤에다 붙여줌
        df.to_csv(FILENAME, encoding='utf-8-sig', index=False, header=False, mode='a')

    return True

# %%
# MBC - 한 기사의 댓글 추출
def getCommentMBC(driver):
    
    import os
    import time
    import pandas as pd
    
    # 데이터를 담을 딕셔너리
    comment_dict = {
        '제목' : [],
        '날짜' : [],
        '작성자' : [],
        '작성일' : [],
        '댓글' : []
    }
    
    # 기사 제목 & 날짜 태그
    a1 = driver.find_element_by_css_selector('#content > div > section.wrap_article > article > div.wrap_title')
    
    # 기사 제목 
    data1 = a1.find_element_by_css_selector('h2').text
    # print(data1)
    
    # 날짜 
    data2 = a1.find_element_by_css_selector('div.ui_article > div.date > span:nth-child(1)').text
    # print(data2)
    
    # 댓글 태그
    a2 = driver.find_elements_by_css_selector('#commentBox > div.list_comment > ul > li')
    # print(len(a2))
        
    # 댓글 수만큼 반복
    for a3 in a2:
        
        # 작성자
        data3 = a3.find_element_by_css_selector('div.u_comment_box > div.user > span.user_id').text
        # print(data3)
        
        # 댓글 작성일
        data4 = a3.find_element_by_css_selector('div.u_comment_box > div.user > span.user_date').text
        # print(data4)
        
        # 댓글 
        data5 = a3.find_element_by_css_selector('div.u_comment_box > div.user_content > div').text
        # print(data5)
        
        # 저장
        comment_dict['제목'].append(data1)
        comment_dict['날짜'].append(data2)
        comment_dict['작성자'].append(data3)
        comment_dict['작성일'].append(data4)
        comment_dict['댓글'].append(data5)
        
        # 답글 버튼 
        a4 = a3.find_element_by_css_selector('div.u_comment_box > div.user_ui_btn > button').text
        # print(a4.split()[-1])
        
        # 답글 버튼 클릭하기
        if a4.split()[-1] != '작성':
            reply_button = a3.find_element_by_css_selector('div.u_comment_box > div.user_ui_btn > button')        
            driver.execute_script("arguments[0].click();", reply_button)  #자바 명령어 실행
            time.sleep(1)
            # print('클릭 완료')
            
            # 답글 태그
            a5 = a3.find_elements_by_css_selector('div.u_wrap_reply > div')
            # print(len(a5))
            
            # 답글 수만큼 반복
            for a6 in a5[:-1]:
                
                # 작성자
                data3 = a6.find_element_by_css_selector('div.user > span.user_id').text
                # print(data3)
                
                # 작성일
                data4 = a6.find_element_by_css_selector('div.user > span.user_date').text
                # print(data4)
                
                # 답글
                data5 = a6.find_element_by_css_selector('div.user_content > div').text
                # print(data5)

                comment_dict['제목'].append(data1)
                comment_dict['날짜'].append(data2)
                comment_dict['작성자'].append(data3)
                comment_dict['작성일'].append(data4)
                comment_dict['댓글'].append(data5)
        
    df = pd.DataFrame(comment_dict)
    df['날짜'] = df['날짜'].str.replace('입력 ', '')
    df['날짜'] = pd.to_datetime(df['날짜'])
    df['작성일'] = pd.to_datetime(df['작성일'])
    display(df)

    FILENAME = 'mbc_comment.csv'
    if os.path.exists(FILENAME) == False:
        # 파일이 없을 경우
        df.to_csv(FILENAME, encoding='utf-8-sig', index=False)
    else:
        # mode='a' : 기존 것 뒤에다 붙여줌
        df.to_csv(FILENAME, encoding='utf-8-sig', index=False, header=False, mode='a')

    return True

# %%
import pandas as pd
from selenium import webdriver as wd
from IPython.display import clear_output
from DaumNews import getDaumNewsUrlDF

# 후보자명
CANDIDATES = ['이재명', '윤석열', '이낙연', '홍준표', '안철수', '정세균', '유승민', '심상정', '추미애', '황교안', '김부겸']
COLOPHON_STR = {'조선일보' : 'chosun', '중앙일보' : 'joongang', '동아일보' : 'donga',
                'JTBC' : 'jtbc', 'MBC' : 'mbc',}

for i in range(len(CANDIDATES)):
    
    if i < 8:
        continue
    
    # 검색어
    KEYWORD = f'대선 {CANDIDATES[i]}'
    print(f'수집한 기사의 키워드는 : {KEYWORD}')

    # 언론
    # 조선일보, 중앙일보, 동아일보, JTBC, 경향신문, MBC 택1
    COLOPHON = 'MBC'

    # 날짜 (YYYYMMDhhmmss)
    dayStart = '20210301000000'
    dayEnd   = '20210514000000'

    # 기사 리스트 가져오기
    df = getDaumNewsUrlDF(KEYWORD=KEYWORD, COLOPHON=COLOPHON, dayStart=dayStart, dayEnd=dayEnd, page=1)
    
    # 크롬 옵션 생성
    options = wd.ChromeOptions()
    # 창 숨기는 옵션 추가
    options.add_argument("headless")
    options.add_argument("disable-gpu")
    
    num_link = df.shape[0]

    idx = 0

    while True :

        # 웹 드라이버
        driver = wd.Chrome('./chromedriver.exe', chrome_options=options)
        driver.implicitly_wait(20)
        clear_output(wait=True)

        driver.get(df.loc[idx].values[0])
#         driver.get('https://news.v.daum.net/v/20210426094106466?f=o')
        driver.refresh()
        source = whichNews(driver)
        if source == 'mbc':
            # 댓글이 없으면
            if not areAnyCommentsMBC(driver):
                print(f'{idx}번째 기사 댓글 없음 다음으로~')

            # 댓글이 있으면
            else:
                print(f'{idx}번째 기사 댓글 수집 중')

                # 더보기 버튼 클릭하기
                clickMoreMBC(driver)
                # 댓글 수집하기
                getCommentMBC(driver)
        else:
            # 댓글이 없으면
            if not areAnyCommentsDaum(driver):
                print(f'{idx}번째 기사 댓글 없음 다음으로~')
                
            else:
                print(f'{idx}번째 기사 댓글 수집 중')
                
                # 더보기 버튼 클릭하기
                clickMoreDaum(driver)
                
                # 댓글 수집하기
                getCommentDaum(driver)
        
        idx += 1
        driver.quit()
        
        if idx == num_link:
            break
            
            
    # 파일명 변경
    import os
    os.rename(f'{COLOPHON}_link.csv', f'{COLOPHON_STR[COLOPHON]}_link_{CANDIDATES[i]}.csv')
    if os.path.isfile(f'{COLOPHON_STR[COLOPHON]}_comment.csv'):
        os.rename(f'{COLOPHON_STR[COLOPHON]}_comment.csv', f'{COLOPHON_STR[COLOPHON]}_comment_{CANDIDATES[i]}.csv')
    if os.path.isfile(f'{COLOPHON_STR[COLOPHON]}_comment_daum.csv'):
        os.rename(f'{COLOPHON_STR[COLOPHON]}_comment_daum.csv', f'{COLOPHON_STR[COLOPHON]}_comment__daum_{CANDIDATES[i]}.csv')
    print(f'{KEYWORD} 키워드 댓글 저장 완료')
# Out:
# 1번째 기사 댓글 수집 중
#                                         제목                  날짜  \
# 0   차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 1   차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 2   차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 3   차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 4   차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 5   차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 6   차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 7   차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 8   차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 9   차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 10  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 11  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 12  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 13  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 14  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 15  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 16  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 17  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 18  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 19  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 20  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 21  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 22  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 23  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 24  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 25  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 26  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 27  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 28  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 29  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 30  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 31  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 32  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 33  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 34  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 35  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 36  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 37  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 38  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
# 39  차기 대선주자 선호도 윤석열 32%·이재명 23.8%·이낙연 9.0% 2021-05-03 09:46:00
#
#                  작성자                 작성일  \
# 0                박현* 2021-05-10 19:55:20
# 1                강영* 2021-05-04 16:55:08
# 2                이현* 2021-05-04 11:53:52
# 3           3495780* 2021-05-03 18:36:22
# 4                박현* 2021-05-10 19:56:25
# 5                한은* 2021-05-11 01:30:31
# 6                전경* 2021-05-03 15:34:01
# 7            952333* 2021-05-03 15:25:21
# 8                김치* 2021-05-03 15:03:29
# 9           Kiki Ki* 2021-05-03 14:59:49
# 10               박봉* 2021-05-03 14:49:57
# 11               김치* 2021-05-03 15:09:50
# 12               김동* 2021-05-03 14:47:15
# 13               박종* 2021-05-03 14:41:00
# 14               송창* 2021-05-03 14:35:53
# 15         monocode* 2021-05-03 14:11:12
# 16               박봉* 2021-05-03 14:22:57
# 17               최인* 2021-05-03 13:43:35
# 18               장대* 2021-05-03 13:36:42
# 19          4886280* 2021-05-03 13:15:10
# 20               박봉* 2021-05-03 13:10:28
# 21  HHCKERproductio* 2021-05-03 13:37:51
# 22          3634766* 2021-05-03 14:07:12
# 23          4107384* 2021-05-03 13:05:52
# 24               박성* 2021-05-03 12:54:42
# 25          Hey Jun* 2021-05-03 12:51:47
# 26               한동* 2021-05-03 12:34:21
# 27               최재* 2021-05-03 12:16:56
# 28               이병* 2021-05-03 12:16:29
# 29          2749441* 2021-05-03 12:13:59
# 30               이재* 2021-05-03 12:05:34
# 31               이선* 2021-05-03 12:01:00
# 32               이태* 2021-05-03 11:25:46
# 33          4999740* 2021-05-03 11:25:36
# 34               이태* 2021-05-03 11:21:00
# 35               이태* 2021-05-03 11:23:59
# 36               이정* 2021-05-03 11:07:38
# 37               홍석* 2021-05-03 11:24:44
# 38          toran a* 2021-05-03 10:53:52
# 39               유영* 2021-05-03 10:49:18
#
#                                                    댓글
# 0   윤석렬은 굴곡이 심하네... 그에 비해 이재명은 꾸준히 상위권이고. 2500명 조사...
# 1                 윤석렬이는 장모 마누라 사기사건 무마로 감빵가야 할것 같은데..
# 2   윤석렬 대선판에서 처가 가족들 비리 까발려지겠구나\n\n의혹이네 수사중이네 무혐의네...
# 3   윤석열·김정숙·문재인이 박원순 살해 혐의로 입건돼 범죄 피의자가 됐다\n\n박원순 ...
# 4                                                 멍멍?
# 5      태극기 부대 대원이신거 같은데 선은 지키세요.\n너무 흉합니다. 부끄러운줄 아세요.
# 6   결혼전이라고 치자 공모를 같이 했다고 트집잡는것도 아니고 제대로 수사를 해달라는 얘...
# 7                            전화응답? 누가 요즘 전화응답하는 사람있냐?
# 8   리얼미터가 구라인건 .. 검증된 일..\n토왜, 국ㄸ당의 사주를 받는 구라 조작 미...
# 9   어떤 애들한테 여론조사를 어케 했는지 모르지만 지금 지지율이 쬐끔 높다고 대통령 될...
# 10  좌파 다합쳐바야40프로도 안됀다..그냥 단일후보만내믄 자동 보수 대통령 .뻬엑뻭 거...
# 11  이 나라의 보수는 진작에 다 죽었고..\n친일 사대 반민족 국민대학살 모리배.. 부...
# 12  ㅋㅋㅋㅋㅋ\n뭘보고 석열이냐???\n이게 진짜라면 촛불시민들은 다 죽은거냐???\n...
# 13                                             개가 웃지요
# 14    로봇찢빠 좋아하는 분들은 이해가 안감...지금처럼 살기 힘든 세상의 연장일텐데....
# 15  국민들 32%는 정신 나갔음?\n검찰 재직 당시 장모가 범죄를 저질것을 비호한\n미...
# 16           결혼 전 니장모가 살인햇음 ..너두살인자냐? 흠이얼마나없길래 그걸로 트집
# 17                                        한국 큰일일쎄....
# 18  이게 의미가 있나? ㅋㅋㅋ 가족관련해서 몇번 떠들면 윤석렬은 나락으로 갈건데 ㅋㅋㅋㅋㅋㅋ
# 19   반기문 60%가 넘었었은데 현재 미세먼지 막고 계시는 중... 지지율 아무 소용 없다.
# 20  국민들 자각이너무늦다...좌파는 수권능력자체가 없는 루저집단이다..김대중 노무현을 ...
# 21  그럼 느그 우파들은 수권능력자체가 있고? 이명바그네 10년은 그럼 어떻게 설명할건데...
# 22  이명박은 사자방으로 자기 주머니에 퍼주고, 박근혜는 순실이한테 퍼주고 얘들 10년 ...
# 23  뭐 이상한 일도 아니지.....\n진짜 빨갱이 새퀴를 국회의원 만드는데도 있던데 뭘...
# 24  부동산정책으로 돌아서도 그쪽으로는 갈수없죠 ,,기권표 던지고말지,,,민주당은 지금이...
# 25  32퍼가 공산국가를 지향하네 ㅋㅋㅋㅋㅋㅋㅋ 석렬이가 민주주의에 어울리나!?? ㅋㅋㅋ...
# 26                  누가 조사한거냐 웃기는 정치판이군 나라 말아먹을 인간이???
# 27              차기 영부인 선호도도 조사해 봐! 쥴리가 과연 몇 등 할지.....
# 28  파렴치함의 끝판왕 윤짜장이 대선선호도 1위라니.. 표적수사와 기소로 검찰을 조폭양아...
# 29  윤석렬이 정치하려고 그런 행보를 한 거구나.\n박정희가 되고 싶었구먼. 아저씨,어림...
# 30  이게 웃기는게 윤석렬은 정치인도 아닌데 왜 후보에 넣은건가요..\n이런 식으로 여론...
# 31  이 때쯤 하는 여론조사 아무 의미없습니다. 과거 1등한 후보 당선되었나요? 아래 리...
# 32  윤석열은 100분 토론만 나와도..\n안철수랑 비슷할 거 같은데..\n안철수는 10...
# 33  와~ 지금껏 살면서 내가 믿고싶지않은 일들이 가끔씩 벌어지는데 어떻게 참고 견뎌야하나 .
# 34              여러분 저거 아~~~무런 의미 없는거 아시죠?\n\n리얼미터에요^^
# 35                                     저랑 앞 두글자 이름이ㅋㅋ
# 36  별로 중요하지 않은....\n민주당이 부동산정책으로 말아먹어도 국짐당이나 검찰깡패는...
# 37                       이성윤은 아직 정치 않하는데 정치깡패라고 하기는..
# 38  지지율은 정말 필요없는 것이 인기투표에 가깝다.. 실제로 대선을 목전에 두면 모두 ...
# 39  아무리 민주당이 싫어도 윤석열은 아니지 않냐~!??\n저런 사람이 대통령?? 어이쿠...

# %%
i
# Out:
# 7
